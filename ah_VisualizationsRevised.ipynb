# %%
# %matplotlib notebook
import numpy as np
import math
import scipy
from scipy import stats
import scipy.stats
import matplotlib.pyplot as plt
import matplotlib.mlab as mlab
import matplotlib.ticker as mtick
from ipywidgets import interact
import pandas as pd
import seaborn as sns
import os
from os import listdir, path
import glob
import tkinter as tk
from tkinter.filedialog import askopenfilename

# %%
def load_data():
    root = tk.Tk()
    root.withdraw() #Prevents the Tkinter window to come up
    samplepath = askopenfilename(multiple=True)
    root.destroy()
    listpath = list(samplepath)
    return listpath

# %%
list_path = load_data()

plus_df = pd.read_csv(list_path[0])

# %%
plus_df
# Out:
#                timestamp  age     sex relationship_status          occupation  \
# 0    2022-04-18 19:18:47   21    Male   In a relationship  University Student
# 1    2022-04-18 19:19:28   21  Female              Single  University Student
# 2    2022-04-18 19:25:59   21  Female              Single  University Student
# 3    2022-04-18 19:29:43   21  Female              Single  University Student
# 4    2022-04-18 19:33:31   21  Female              Single  University Student
# ..                   ...  ...     ...                 ...                 ...
# 476  2022-05-21 23:38:28   24    Male              Single     Salaried Worker
# 477  2022-05-22 00:01:05   26  Female             Married     Salaried Worker
# 478  2022-05-22 10:29:21   29  Female             Married     Salaried Worker
# 479  2022-07-14 19:33:47   21    Male              Single  University Student
# 480  2022-11-12 13:16:50   53    Male             Married     Salaried Worker
#
#     affiliated_organization  social_media_user  \
# 0                University                  1
# 1                University                  1
# 2                University                  1
# 3                University                  1
# 4                University                  1
# ..                      ...                ...
# 476     University, Private                  1
# 477              University                  1
# 478              University                  1
# 479              University                  1
# 480                 Private                  1
#
#                                  common_platforms_used  \
# 0    ['Facebook', 'Twitter', 'Instagram', 'YouTube'...
# 1    ['Facebook', 'Twitter', 'Instagram', 'YouTube'...
# 2    ['Facebook', 'Instagram', 'YouTube', 'Pinterest']
# 3                            ['Facebook', 'Instagram']
# 4                 ['Facebook', 'Instagram', 'YouTube']
# ..                                                 ...
# 476               ['Facebook', 'Instagram', 'YouTube']
# 477                            ['Facebook', 'YouTube']
# 478                            ['Facebook', 'YouTube']
# 479  ['Facebook', 'Twitter', 'Instagram', 'YouTube'...
# 480                            ['Facebook', 'YouTube']
#
#      average_hours_spent_daily  frequency_use_without_purpose  ...  company  \
# 0                            3                              5  ...        0
# 1                            6                              4  ...        0
# 2                            4                              3  ...        0
# 3                            6                              4  ...        0
# 4                            3                              3  ...        0
# ..                         ...                            ...  ...      ...
# 476                          3                              3  ...        0
# 477                          2                              2  ...        0
# 478                          3                              3  ...        0
# 479                          3                              2  ...        0
# 480                          1                              2  ...        0
#
#      goverment    age_group  age_group_ordinal  adhd  anxiety  \
# 0            0        young                  1  4.50      2.0
# 1            0        young                  1  3.75      3.5
# 2            0        young                  1  2.75      3.0
# 3            0        young                  1  3.00      3.0
# 4            0        young                  1  4.25      4.5
# ..         ...          ...                ...   ...      ...
# 476          0        young                  1  3.75      3.0
# 477          0        young                  1  2.50      3.0
# 478          0        young                  1  3.00      3.0
# 479          0        young                  1  2.50      2.5
# 480          0  older_adult                  3  2.25      1.0
#
#      self_esteem_issues  depression  total_avg_score  has_issues
# 0              2.333333    4.666667         3.375000           0
# 1              3.666667    4.666667         3.895833           1
# 2              2.333333    3.666667         2.937500           0
# 3              4.000000    3.000000         3.250000           0
# 4              3.000000    3.000000         3.687500           1
# ..                  ...         ...              ...         ...
# 476            4.000000    3.666667         3.604167           1
# 477            4.000000    3.000000         3.125000           0
# 478            3.333333    2.000000         2.833333           0
# 479            3.000000    4.333333         3.083333           0
# 480            2.666667    2.333333         2.062500           0
#
# [481 rows x 46 columns]

# %%
plus_list = list(plus_df.columns.values)
test_pd = plus_df.groupby(['sex'])[['average_hours_spent_daily', 'frequency_use_without_purpose', 'anxiety', 'self_esteem_issues']].count()
test_pd
#test_pd.plot.bar(stacked = True, figsize = (9,5))
colors = ['darkblue', 'lightblue', 'grey']
test_pd.plot.pie(subplots = True, colors = colors, figsize = (14,5))
# Out:
# <img src="data:image/png;base64,..." width="1400">
# array([<AxesSubplot:ylabel='average_hours_spent_daily'>,
#        <AxesSubplot:ylabel='frequency_use_without_purpose'>,
#        <AxesSubplot:ylabel='anxiety'>,
#        <AxesSubplot:ylabel='self_esteem_issues'>], dtype=object)

# %%
test_pd = plus_df.groupby(['sex'])[['average_hours_spent_daily', 'frequency_use_without_purpose', 'anxiety', 'self_esteem_issues']].count()
colors = ['darkblue', 'lightblue', 'grey']
test_pd.plot.pie(subplots = True, colors = colors, figsize = (14,5))

# %%
test_pd = plus_df.groupby([plus_list[8]])[['age', 'sex', 'anxiety', 'depression', 'adhd', 'self_esteem_issues']].count()
colors = ['darkblue', 'lightblue', 'grey']
test_pd.plot.bar(stacked=True, figsize=(10, 5))
# Out:
# <img src="data:image/png;base64,..." width="1000">
# <AxesSubplot:xlabel='average_hours_spent_daily'>

# %%
test_pd = plus_df.groupby(['anxiety'])[[plus_list[8]]].mean()
test_pd.plot.bar(figsize=(10, 5))
# Out:
# <img src="data:image/png;base64,..." width="1000">
# <AxesSubplot:xlabel='anxiety'>

# %%
test_pd = plus_df.groupby(['depression'])[[plus_list[8]]].mean()
test_pd.plot.bar(figsize=(10, 9))
# Out:
# <img src="data:image/png;base64,..." width="1000">
# <AxesSubplot:xlabel='depression'>

# %%
test_pd = plus_df.groupby(['adhd'])[[plus_list[8]]].mean()
test_pd.plot.bar(figsize=(10, 6))
# Out:
# <img src="data:image/png;base64,..." width="1000">
# <AxesSubplot:xlabel='adhd'>

# %%
test_pd = plus_df.groupby(['self_esteem_issues'])[[plus_list[8]]].mean()
test_pd.plot.bar(figsize=(10, 7))
# Out:
# <img src="data:image/png;base64,..." width="1000">
# <AxesSubplot:xlabel='self_esteem_issues'>
