# %%
#Importing libraries

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
# Dataset load

df=pd.read_csv('../datasets/cleaned_data.csv')

# %%
# Choosing numerical colums for visualization

numerical_columns=['age','average_hours_spent_daily','worried_level','difficulty_concentrating']

# %%
# Calculate the mean, median, and standard deviation of the "Age" column
age_mean = df['age'].mean()
age_median = df['age'].median()
age_std = df['age'].std()

# Display the results
print("Mean Age:", age_mean)
print("Median Age:", age_median)
print("Standard Deviation of Age:", age_std)
# Out:
# Mean Age: 26.135135135135137
# Median Age: 22.0
# Standard Deviation of Age: 9.915078607040076

# %%
# Calculate the mean, median, and standard deviation of the "Age" column
average_hours_spent_daily_mean = df['average_hours_spent_daily'].mean()
average_hours_spent_daily_median = df['average_hours_spent_daily'].median()
average_hours_spent_daily_std = df['average_hours_spent_daily'].std()

# Display the results
print("Mean average_hours_spent_daily:", average_hours_spent_daily_mean)
print("Median average_hours_spent_daily:", average_hours_spent_daily_median)
print("Standard Deviation of average_hours_spent_daily:", average_hours_spent_daily_std)
# Out:
# Mean average_hours_spent_daily: 3.9085239085239087
# Median average_hours_spent_daily: 4.0
# Standard Deviation of average_hours_spent_daily: 1.5903190534023957

# %%
# Calculate the mean, median, and standard deviation of the "Age" column
worried_level_mean = df['worried_level'].mean()
worried_level_median = df['worried_level'].median()
worried_level_std = df['worried_level'].std()

# Display the results
print("Mean worried_level:", worried_level_mean)
print("Median worried_level:", worried_level_median)
print("Standard Deviation of worried_level:", worried_level_std)
# Out:
# Mean worried_level: 3.5592515592515594
# Median worried_level: 4.0
# Standard Deviation of worried_level: 1.2833560581548566

# %%
# Calculate the mean, median, and standard deviation of the "Age" column
difficulty_concentrating_mean = df['difficulty_concentrating'].mean()
difficulty_concentrating_median = df['difficulty_concentrating'].median()
difficulty_concentrating_std = df['difficulty_concentrating'].std()

# Display the results
print("Mean difficulty_concentrating:", difficulty_concentrating_mean)
print("Median difficulty_concentrating:", difficulty_concentrating_median)
print("Standard Deviation of difficulty_concentrating:", difficulty_concentrating_std)
# Out:
# Mean difficulty_concentrating: 3.2453222453222454
# Median difficulty_concentrating: 3.0
# Standard Deviation of difficulty_concentrating: 1.347104901146015

# %%
# Bar plot average_hours_spent_daily vs. depression
sns.barplot(x='average_hours_spent_daily', y='depression', data=df)
plt.title('Bar Plot: average_hours_spent_daily vs. depression')
plt.show()

sns.lineplot(x='average_hours_spent_daily', y='depression', data=df)
plt.title('line Plot: average_hours_spent_daily vs. depression')
plt.show()

# %%
# Bar plot average_hours_spent_daily vs. self_esteem_issues
sns.barplot(x='average_hours_spent_daily', y='self_esteem_issues', data=df)
plt.title('Bar Plot: average_hours_spent_daily vs. self_esteem_issues')
plt.show()

sns.lineplot(x='average_hours_spent_daily', y='self_esteem_issues', data=df)
plt.title('line Plot: average_hours_spent_daily vs. self_esteem_issues')
plt.show()

# %%
# Bar plot average_hours_spent_daily vs. anxiety
sns.barplot(x='average_hours_spent_daily', y='anxiety', data=df)
plt.title('Bar Plot: average_hours_spent_daily vs. anxiety')
plt.show()

sns.lineplot(x='average_hours_spent_daily', y='anxiety', data=df)
plt.title('line Plot: average_hours_spent_daily vs. anxiety')
plt.show()

# %%
# Bar plot average_hours_spent_daily vs. difficulty_concentrating
sns.barplot(x='average_hours_spent_daily', y='difficulty_concentrating', data=df)
plt.title('Bar Plot: average_hours_spent_daily vs. difficulty_concentrating')
plt.show()

sns.lineplot(x='average_hours_spent_daily', y='difficulty_concentrating', data=df)
plt.title('Line Plot: average_hours_spent_daily vs. difficulty_concentrating')
plt.show()

# %%
# Bar plot average_hours_spent_daily vs. restless_without_social_media
sns.barplot(x='average_hours_spent_daily', y='restless_without_social_media', data=df)
plt.title('Bar Plot: average_hours_spent_daily vs. restless_without_social_media')
plt.show()

# Line plot
sns.lineplot(x='average_hours_spent_daily', y='restless_without_social_media', data=df)
plt.title('Line Plot: average_hours_spent_daily vs. restless_without_social_media')
plt.show()

# %%
# Bar plot average_hours_spent_daily vs. easily_distracted
sns.barplot(x='average_hours_spent_daily', y='easily_distracted', data=df)
plt.title('Bar Plot: average_hours_spent_daily vs. easily_distracted')
plt.show()

sns.lineplot(x='average_hours_spent_daily', y='easily_distracted', data=df)
plt.title('Line Plot: average_hours_spent_daily vs. easily_distracted')
plt.show()

# %%
# Create age groups
#bins = [10, 20, 30, 40, 50, 60, 70]  # Define your age group bins
#labels = ['10-19','20-29', '30-39', '40-49', '50-59', '60-69']
#df['AgeGroup'] = pd.cut(df['age'], bins=bins, labels=labels, right=False)

bins = [0, 30, 40, np.inf]
labels = ['young', 'adult', 'older_adult']
df['AgeGroup'] = pd.cut(df['age'], bins=bins, labels=labels)

# %%
# Bar plot AgeGroup vs. easily_distracted
sns.barplot(x='AgeGroup', y='easily_distracted', data=df)
plt.title('Bar Plot: AgeGroup vs. easily_distracted')
plt.show()

sns.lineplot(x='AgeGroup', y='easily_distracted', data=df)
plt.title('Line Plot: AgeGroup vs. easily_distracted')
plt.show()

# %%
# Bar plot AgeGroup vs. restless_without_social_media
sns.barplot(x='AgeGroup', y='restless_without_social_media', data=df)
plt.title('Bar Plot: AgeGroup vs. restless_without_social_media')
plt.show()

sns.lineplot(x='AgeGroup', y='restless_without_social_media', data=df)
plt.title('Line Plot: AgeGroup vs. restless_without_social_media')
plt.show()

# %%
# Bar plot AgeGroup vs. anxiety
sns.barplot(x='AgeGroup', y='anxiety', data=df)
plt.title('Bar Plot: AgeGroup vs. anxiety')
plt.show()

sns.lineplot(x='AgeGroup', y='anxiety', data=df)
plt.title('Line Plot: AgeGroup vs. anxiety')
plt.show()

# %%
# Bar plot AgeGroup vs. difficulty_concentrating
sns.barplot(x='AgeGroup', y='difficulty_concentrating', data=df)
plt.title('Bar Plot: AgeGroup vs. difficulty_concentrating')
plt.show()

sns.lineplot(x='AgeGroup', y='difficulty_concentrating', data=df)
plt.title('Line Plot: AgeGroup vs. difficulty_concentrating')
plt.show()

# %%
# Bar plot AgeGroup vs. depression
sns.barplot(x='AgeGroup', y='depression', data=df)
plt.title('Bar Plot: AgeGroup vs. depression')
plt.show()

sns.lineplot(x='AgeGroup', y='depression', data=df)
plt.title('Line Plot: AgeGroup vs. depression')
plt.show()

# %%
# Bar plot AgeGroup vs. difficulty_concentrating
sns.barplot(x='AgeGroup', y='self_esteem_issues', data=df)
plt.title('Bar Plot: AgeGroup vs. self_esteem_issues')
plt.show()
